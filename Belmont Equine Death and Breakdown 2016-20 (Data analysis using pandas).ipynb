# %%
import pandas as pd

# %%
# !ls
# Out:
# Belmont Equine_Death_and_Breakdown (2016).csv
# Belmont Equine_Death_and_Breakdown (2017).csv
# Belmont Equine_Death_and_Breakdown (2018).csv
# Belmont Equine_Death_and_Breakdown (2019).csv
# Belmont Equine_Death_and_Breakdown (2020).csv
# Belmont Equine_Death_and_Breakdown Five Years.csv
# Belmont Equine_Death_and_Breakdown Trainers.csv
# Untitled.ipynb
# untitled.txt

# %%
df = pd.read_csv("Belmont Equine_Death_and_Breakdown Trainers.csv")

# %%
df.columns
# Out:
# Index(['Year', 'Incident Date', 'Incident Type', 'Track', 'Inv Location',
#        'Racing Type Description', 'Division', 'Weather Conditions', 'Horse',
#        'Trainer', 'Jockey Driver', 'Incident Description', 'Death or Injury'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                        int64
# Incident Date              object
# Incident Type              object
# Track                      object
# Inv Location               object
# Racing Type Description    object
# Division                   object
# Weather Conditions         object
# Horse                      object
# Trainer                    object
# Jockey Driver              object
# Incident Description       object
# Death or Injury            object
# dtype: object

# %%
df.Trainer.value_counts()
# Out:
# RODOLFO (RUDY) RODRIGUEZ    13
# JEREMIAH C. ENGLEHART       10
# TODD A. PLETCHER             9
# CHARLTON A. BAKER            8
# GARY C. CONTESSA             8
#                             ..
# LUIS A. MIRANDA              1
# DOUG F. O'NEILL              1
# ARTHUR B. MAGNUSON           1
# JASON SERVIS                 1
# URIAH A. ST LEWIS            1
# Name: Trainer, Length: 126, dtype: int64

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df.columns
# Out:
# Index(['Year', 'IncidentDate', 'IncidentType', 'Track', 'InvLocation',
#        'RacingTypeDescription', 'Division', 'WeatherConditions', 'Horse',
#        'Trainer', 'JockeyDriver', 'IncidentDescription', 'DeathorInjury'],
#       dtype='object')

# %%
df.IncidentType.value_counts()
# Out:
# EQUINE DEATH                         205
# RACING INCIDENT                       83
# RACING INJURY                         26
# FALL OF RIDER                         11
# FALL OF HORSE                          4
# STEWARDS/VETS LIST                     2
# EQUINE DEATH - INFECTIOUS DISEASE      1
# Name: IncidentType, dtype: int64

# %%
df.IncidentType == 'EQUINE DEATH'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 327     True
# 328     True
# 329     True
# 330     True
# 331     True
# Name: IncidentType, Length: 332, dtype: bool

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2016)]
# Out:
#      Year IncidentDate  IncidentType                Track  \
# 11   2016   12/10/2016  EQUINE DEATH  Belmont Park (NYRA)
# 17   2016   10/21/2016  EQUINE DEATH  Belmont Park (NYRA)
# 48   2016   04/09/2016  EQUINE DEATH  Belmont Park (NYRA)
# 50   2016   06/04/2016  EQUINE DEATH  Belmont Park (NYRA)
# 54   2016   09/30/2016  EQUINE DEATH  Belmont Park (NYRA)
# 59   2016   10/03/2016  EQUINE DEATH  Belmont Park (NYRA)
# 66   2016   01/30/2016  EQUINE DEATH  Belmont Park (NYRA)
# 67   2016   10/20/2016  EQUINE DEATH  Belmont Park (NYRA)
# 68   2016   12/05/2016  EQUINE DEATH  Belmont Park (NYRA)
# 71   2016   01/29/2016  EQUINE DEATH  Belmont Park (NYRA)
# 72   2016   06/08/2016  EQUINE DEATH  Belmont Park (NYRA)
# 88   2016   06/04/2016  EQUINE DEATH  Belmont Park (NYRA)
# 89   2016   10/17/2016  EQUINE DEATH  Belmont Park (NYRA)
# 90   2016   10/19/2016  EQUINE DEATH  Belmont Park (NYRA)
# 96   2016   01/22/2016  EQUINE DEATH  Belmont Park (NYRA)
# ...

# %%
len(df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2016)])
# Out:
# 39

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2017)]
# Out:
#      Year IncidentDate  IncidentType                Track  \
# 5    2017   06/03/2017  EQUINE DEATH  Belmont Park (NYRA)
# 9    2017   10/21/2017  EQUINE DEATH  Belmont Park (NYRA)
# 18   2017   04/28/2017  EQUINE DEATH  Belmont Park (NYRA)
# 19   2017   02/26/2017  EQUINE DEATH  Belmont Park (NYRA)
# 32   2017   05/07/2017  EQUINE DEATH  Belmont Park (NYRA)
# 35   2017   12/09/2017  EQUINE DEATH  Belmont Park (NYRA)
# 43   2017   09/20/2017  EQUINE DEATH  Belmont Park (NYRA)
# 44   2017   11/25/2017  EQUINE DEATH  Belmont Park (NYRA)
# 57   2017   09/01/2017  EQUINE DEATH  Belmont Park (NYRA)
# 60   2017   06/21/2017  EQUINE DEATH  Belmont Park (NYRA)
# 62   2017   04/30/2017  EQUINE DEATH  Belmont Park (NYRA)
# 63   2017   02/27/2017  EQUINE DEATH  Belmont Park (NYRA)
# 64   2017   10/26/2017  EQUINE DEATH  Belmont Park (NYRA)
# 77   2017   06/29/2017  EQUINE DEATH  Belmont Park (NYRA)
# 80   2017   11/16/2017  EQUINE DEATH  Belmont Park (NYRA)
# ...

# %%
len(df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2017)])
# Out:
# 41

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2018)]
# Out:
#      Year IncidentDate  IncidentType                Track  \
# 4    2018   09/21/2018  EQUINE DEATH  Belmont Park (NYRA)
# 13   2018   09/30/2018  EQUINE DEATH  Belmont Park (NYRA)
# 14   2018   04/06/2018  EQUINE DEATH  Belmont Park (NYRA)
# 16   2018   11/05/2018  EQUINE DEATH  Belmont Park (NYRA)
# 34   2018   01/07/2018  EQUINE DEATH  Belmont Park (NYRA)
# 45   2018   10/14/2018  EQUINE DEATH  Belmont Park (NYRA)
# 52   2018   06/03/2018  EQUINE DEATH  Belmont Park (NYRA)
# 93   2018   07/30/2018  EQUINE DEATH  Belmont Park (NYRA)
# 94   2018   09/07/2018  EQUINE DEATH  Belmont Park (NYRA)
# 102  2018   12/25/2018  EQUINE DEATH  Belmont Park (NYRA)
# 103  2018   06/17/2018  EQUINE DEATH  Belmont Park (NYRA)
# 121  2018   12/07/2018  EQUINE DEATH  Belmont Park (NYRA)
# 137  2018   05/03/2018  EQUINE DEATH  Belmont Park (NYRA)
# 148  2018   05/24/2018  EQUINE DEATH  Belmont Park (NYRA)
# 168  2018   01/19/2018  EQUINE DEATH  Belmont Park (NYRA)
# ...

# %%
len(df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2018)])
# Out:
# 29

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2019)]
# Out:
#      Year IncidentDate  IncidentType                Track  \
# 3    2019   11/02/2019  EQUINE DEATH  Belmont Park (NYRA)
# 6    2019   06/16/2019  EQUINE DEATH  Belmont Park (NYRA)
# 15   2019   05/11/2019  EQUINE DEATH  Belmont Park (NYRA)
# 24   2019   09/20/2019  EQUINE DEATH  Belmont Park (NYRA)
# 25   2019   03/10/2019  EQUINE DEATH  Belmont Park (NYRA)
# 26   2019   05/24/2019  EQUINE DEATH  Belmont Park (NYRA)
# 37   2019   04/01/2019  EQUINE DEATH  Belmont Park (NYRA)
# 49   2019   01/29/2019  EQUINE DEATH  Belmont Park (NYRA)
# 58   2019   02/04/2019  EQUINE DEATH  Belmont Park (NYRA)
# 78   2019   11/24/2019  EQUINE DEATH  Belmont Park (NYRA)
# 92   2019   11/11/2019  EQUINE DEATH  Belmont Park (NYRA)
# 106  2019   12/21/2019  EQUINE DEATH  Belmont Park (NYRA)
# 110  2019   04/11/2019  EQUINE DEATH  Belmont Park (NYRA)
# 114  2019   09/21/2019  EQUINE DEATH  Belmont Park (NYRA)
# 116  2019   09/19/2019  EQUINE DEATH  Belmont Park (NYRA)
# ...

# %%
len(df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2019)])
# Out:
# 44

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2020)]
# Out:
#      Year IncidentDate  IncidentType                Track  \
# 2    2020   10/05/2020  EQUINE DEATH  Belmont Park (NYRA)
# 31   2020   06/27/2020  EQUINE DEATH  Belmont Park (NYRA)
# 33   2020   08/22/2020  EQUINE DEATH  Belmont Park (NYRA)
# 36   2020   05/25/2020  EQUINE DEATH  Belmont Park (NYRA)
# 38   2020   05/18/2020  EQUINE DEATH  Belmont Park (NYRA)
# 40   2020   05/28/2020  EQUINE DEATH  Belmont Park (NYRA)
# 47   2020   07/30/2020  EQUINE DEATH  Belmont Park (NYRA)
# 51   2020   08/30/2020  EQUINE DEATH  Belmont Park (NYRA)
# 55   2020   06/04/2020  EQUINE DEATH  Belmont Park (NYRA)
# 65   2020   07/14/2020  EQUINE DEATH  Belmont Park (NYRA)
# 74   2020   05/31/2020  EQUINE DEATH  Belmont Park (NYRA)
# 75   2020   10/08/2020  EQUINE DEATH  Belmont Park (NYRA)
# 79   2020   11/05/2020  EQUINE DEATH  Belmont Park (NYRA)
# 82   2020   05/31/2020  EQUINE DEATH  Belmont Park (NYRA)
# 84   2020   01/03/2020  EQUINE DEATH  Belmont Park (NYRA)
# ...

# %%
len(df[(df.IncidentType == 'EQUINE DEATH') & (df.Year == 2020)])
# Out:
# 52

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Trainer == 'RODOLFO (RUDY) RODRIGUEZ')]
# Out:
#      Year IncidentDate  IncidentType                Track  \
# 268  2020   01/20/2020  EQUINE DEATH  Belmont Park (NYRA)
# 270  2016   10/20/2016  EQUINE DEATH  Belmont Park (NYRA)
# 272  2019   09/12/2019  EQUINE DEATH  Belmont Park (NYRA)
# 276  2018   10/28/2018  EQUINE DEATH  Belmont Park (NYRA)
# 277  2020   11/03/2020  EQUINE DEATH  Belmont Park (NYRA)
# 278  2019   06/09/2019  EQUINE DEATH  Belmont Park (NYRA)
#
#                 InvLocation RacingTypeDescription      Division  \
# 268  Belmont training track              Training  Thoroughbred
# 270                   Stall                 Other  Thoroughbred
# 272                     NaN                Racing  Thoroughbred
# 276                     NaN                 Other  Thoroughbred
# 277            Belmont Main              Training  Thoroughbred
# 278              3/8th pole                Racing  Thoroughbred
#
#     WeatherConditions            Horse                   Trainer  \
# ...

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Trainer == 'JEREMIAH C. ENGLEHART')]
# Out:
#      Year IncidentDate  IncidentType                Track  \
# 125  2016   01/02/2016  EQUINE DEATH  Belmont Park (NYRA)
# 126  2016   11/12/2016  EQUINE DEATH  Belmont Park (NYRA)
# 127  2019   02/03/2019  EQUINE DEATH  Belmont Park (NYRA)
# 129  2020   07/20/2020  EQUINE DEATH  Belmont Park (NYRA)
# 130  2019   09/06/2019  EQUINE DEATH  Belmont Park (NYRA)
# 131  2019   09/06/2019  EQUINE DEATH  Belmont Park (NYRA)
# 133  2019   04/04/2019  EQUINE DEATH  Belmont Park (NYRA)
#
#                  InvLocation RacingTypeDescription      Division  \
# 125  Training Track-1/8 pole              Training  Thoroughbred
# 126              Finish line              Training  Thoroughbred
# 127   Belmont Training Track              Training  Thoroughbred
# 129              Stable Area                 Other  Thoroughbred
# 130        Belmont Racetrack                Racing  Thoroughbred
# 131                      NaN              Training  Thoroughbred
# ...

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Trainer == 'TODD A. PLETCHER')]
# Out:
#      Year IncidentDate  IncidentType                Track     InvLocation  \
# 301  2020   10/09/2020  EQUINE DEATH  Belmont Park (NYRA)    Belmont Park
# 302  2018   08/06/2018  EQUINE DEATH  Belmont Park (NYRA)  Training Track
# 303  2019   01/19/2019  EQUINE DEATH  Belmont Park (NYRA)     Finish line
# 304  2018   06/07/2018  EQUINE DEATH  Belmont Park (NYRA)        1/8 pole
# 307  2018   01/09/2018  EQUINE DEATH  Belmont Park (NYRA)   1/2 mile pole
# 308  2019   07/27/2019  EQUINE DEATH  Belmont Park (NYRA)    Belmont Park
#
#     RacingTypeDescription      Division WeatherConditions            Horse  \
# 301                 Other  Thoroughbred                68        Blackjack
# 302              Training  Thoroughbred               NaN        Gabriella
# 303              Training  Thoroughbred         35* Clear            Speke
# 304              Training  Thoroughbred        60* Cloudy          Montauk
# ...

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Trainer == 'CHARLTON A. BAKER')]
# Out:
#     Year IncidentDate  IncidentType                Track  \
# 34  2018   01/07/2018  EQUINE DEATH  Belmont Park (NYRA)
# 35  2017   12/09/2017  EQUINE DEATH  Belmont Park (NYRA)
# 36  2020   05/25/2020  EQUINE DEATH  Belmont Park (NYRA)
# 37  2019   04/01/2019  EQUINE DEATH  Belmont Park (NYRA)
# 38  2020   05/18/2020  EQUINE DEATH  Belmont Park (NYRA)
# 40  2020   05/28/2020  EQUINE DEATH  Belmont Park (NYRA)
#
#                InvLocation RacingTypeDescription      Division  \
# 34                 Belmont                 Other  Thoroughbred
# 35                1/8 pole              Training  Thoroughbred
# 36              Elmont, NY                 Other  Thoroughbred
# 37             Finish line              Training  Thoroughbred
# 38        Ruffian Hospital                 Other  Thoroughbred
# 40  Belmont Training track              Training  Thoroughbred
#
#    WeatherConditions               Horse            Trainer    JockeyDriver  \
# ...

# %%
df[(df.IncidentType == 'EQUINE DEATH') & (df.Trainer == 'GARY C. CONTESSA')]
# Out:
#     Year IncidentDate  IncidentType                Track          InvLocation  \
# 88  2016   06/04/2016  EQUINE DEATH  Belmont Park (NYRA)           Belmont TT
# 89  2016   10/17/2016  EQUINE DEATH  Belmont Park (NYRA)           Belmont TT
# 90  2016   10/19/2016  EQUINE DEATH  Belmont Park (NYRA)  Belmont TT-1/8 pole
# 91  2020   05/04/2020  EQUINE DEATH  Belmont Park (NYRA)                  NaN
# 92  2019   11/11/2019  EQUINE DEATH  Belmont Park (NYRA)           Belmont TT
# 93  2018   07/30/2018  EQUINE DEATH  Belmont Park (NYRA)       training track
# 94  2018   09/07/2018  EQUINE DEATH  Belmont Park (NYRA)                  NaN
#
#    RacingTypeDescription      Division WeatherConditions               Horse  \
# 88              Training  Thoroughbred      Sunny  Clear    Riding the Rails
# 89              Training  Thoroughbred               NaN   The Silver Frisby
# 90              Training  Thoroughbred               NaN  A Chip and a Chair
# ...
